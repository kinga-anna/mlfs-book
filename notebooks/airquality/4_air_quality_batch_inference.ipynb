# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import sys
from pathlib import Path
import os

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml


if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Read the API keys and configuration variables from the file <root_dir>/.env
from mlfs import config
if os.path.exists(f"{root_dir}/.env"):
    settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /mnt/c/Users/kokia/Documents/egyetem/autumn-25/period2/scalableML/mlfs-book
# HopsworksSettings initialized!

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from mlfs.airquality import util

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2025, 11, 14, 11, 55, 7, 386201)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
project = hopsworks.login()
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# 2025-11-14 11:55:07,400 INFO: Initializing external client
# 2025-11-14 11:55:07,401 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-14 11:55:08,384 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-14 11:55:09,297 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1286340

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()

retrieved_model = mr.get_model(
    name="air_quality_xgboost_model_wlag",
    version=1,
)

fv = retrieved_model.get_feature_view()

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# 2025-11-14 11:55:13,650 INFO: Initializing for batch retrieval of feature vectors
# Downloading: 0.000%|          | 0/535732 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 1 files)...
# Downloading: 0.000%|          | 0/116010 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 2 files)...
# Downloading: 0.000%|          | 0/21917 elapsed<00:00 remaining<?
# Downloading model artifact (1 dirs, 3 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='2.1444763E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float', 'float'],
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >= today).read()
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.83s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-16 00:00:00+00:00                 3.25                0.0
# 1 2025-11-18 00:00:00+00:00                -1.35                0.0
# 2 2025-11-17 00:00:00+00:00                 0.65                0.0
# 3 2025-11-19 00:00:00+00:00                 0.50                0.0
# 4 2025-11-15 00:00:00+00:00                 1.45                0.0
# 5 2025-11-20 00:00:00+00:00                -1.40                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city
# 0           10.787993                   244.290100  Stockholm
# 1            8.699793                   294.443939  Stockholm
# 2           11.681987                   326.309906  Stockholm
# 3           13.854155                    24.567156  Stockholm
# 4           10.853866                   275.710510  Stockholm
# 5            8.350138                   352.568695  Stockholm

# %% [markdown]
# ## <span style="color:#ff5f27;">📊 Get Historical PM2.5 Data for Lag Features  </span>

# %%
# Get the air quality feature group with lag features
air_quality_fg = fs.get_feature_group(name='air_quality_lag', version=1)

# Get the last 3 days of historical data (before today)
historical_data = air_quality_fg.select(['pm25', 'date']).read().sort_values("date")
last_3 = historical_data["pm25"].tail(3)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.17s)

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions sequentially</span>

# %%
# Sort batch_data by date to ensure sequential predictions
batch_data = batch_data.sort_values('date').reset_index(drop=True)

# last_3 list will store the "current" last 3 days' lagged mean

# Make predictions sequentially
predictions = []
for idx, row in batch_data.iterrows():
    # Calculate pm25_lag_mean from the last 3 values
    pm25_lag_mean = last_3.mean()
    
    # Prepare features for prediction
    features = pd.DataFrame({
        'pm25_lag_mean': [pm25_lag_mean],
        'temperature_2m_mean': [row['temperature_2m_mean']],
        'precipitation_sum': [row['precipitation_sum']],
        'wind_speed_10m_max': [row['wind_speed_10m_max']],
        'wind_direction_10m_dominant': [row['wind_direction_10m_dominant']]
    })
    
    # Make prediction
    predicted_pm25 = retrieved_xgboost_model.predict(features)[0]
    predictions.append(predicted_pm25)
    
    # Add the prediction to history for next iteration
    last_3 = pd.concat([last_3.iloc[1:], pd.Series([predicted_pm25])], ignore_index=True)

    
    print(f"Date: {row['date'].date()}, pm25_lag_mean: {pm25_lag_mean:.2f}, predicted_pm25: {predicted_pm25:.2f}")

# Add predictions to batch_data
batch_data['predicted_pm25'] = predictions
batch_data
# Out:
# Date: 2025-11-15, pm25_lag_mean: 9.00, predicted_pm25: 11.77
# Date: 2025-11-16, pm25_lag_mean: 8.92, predicted_pm25: 9.64
# Date: 2025-11-17, pm25_lag_mean: 10.14, predicted_pm25: 10.48
# Date: 2025-11-18, pm25_lag_mean: 10.63, predicted_pm25: 13.98
# Date: 2025-11-19, pm25_lag_mean: 11.37, predicted_pm25: 11.77
# Date: 2025-11-20, pm25_lag_mean: 12.08, predicted_pm25: 18.84
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-15 00:00:00+00:00                 1.45                0.0
# 1 2025-11-16 00:00:00+00:00                 3.25                0.0
# 2 2025-11-17 00:00:00+00:00                 0.65                0.0
# 3 2025-11-18 00:00:00+00:00                -1.35                0.0
# 4 2025-11-19 00:00:00+00:00                 0.50                0.0
# 5 2025-11-20 00:00:00+00:00                -1.40                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25
# 0           10.853866                   275.710510  Stockholm       11.771300
# 1           10.787993                   244.290100  Stockholm        9.642936
# 2           11.681987                   326.309906  Stockholm       10.481404
# 3            8.699793                   294.443939  Stockholm       13.980279
# 4           13.854155                    24.567156  Stockholm       11.773286
# 5            8.350138                   352.568695  Stockholm       18.841528

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         6 non-null      datetime64[us, Etc/UTC]
#  1   temperature_2m_mean          6 non-null      float32
#  2   precipitation_sum            6 non-null      float32
#  3   wind_speed_10m_max           6 non-null      float32
#  4   wind_direction_10m_dominant  6 non-null      float32
#  5   city                         6 non-null      object
#  6   predicted_pm25               6 non-null      float32
# dtypes: datetime64[us, Etc/UTC](1), float32(5), object(1)
# memory usage: 344.0+ bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data = batch_data.sort_values(by=['date'])
batch_data
# Out:
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-15 00:00:00+00:00                 1.45                0.0
# 1 2025-11-16 00:00:00+00:00                 3.25                0.0
# 2 2025-11-17 00:00:00+00:00                 0.65                0.0
# 3 2025-11-18 00:00:00+00:00                -1.35                0.0
# 4 2025-11-19 00:00:00+00:00                 0.50                0.0
# 5 2025-11-20 00:00:00+00:00                -1.40                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25  \
# 0           10.853866                   275.710510  Stockholm       11.771300
# 1           10.787993                   244.290100  Stockholm        9.642936
# 2           11.681987                   326.309906  Stockholm       10.481404
# 3            8.699793                   294.443939  Stockholm       13.980279
# 4           13.854155                    24.567156  Stockholm       11.773286
# 5            8.350138                   352.568695  Stockholm       18.841528
#
#                   street country  days_before_forecast_day
# 0  Sollentuna-E4-Häggvik  Sweden                         1
# 1  Sollentuna-E4-Häggvik  Sweden                         2
# 2  Sollentuna-E4-Häggvik  Sweden                         3
# 3  Sollentuna-E4-Häggvik  Sweden                         4
# 4  Sollentuna-E4-Häggvik  Sweden                         5
# 5  Sollentuna-E4-Häggvik  Sweden                         6

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         6 non-null      datetime64[us, Etc/UTC]
#  1   temperature_2m_mean          6 non-null      float32
#  2   precipitation_sum            6 non-null      float32
#  3   wind_speed_10m_max           6 non-null      float32
#  4   wind_direction_10m_dominant  6 non-null      float32
#  5   city                         6 non-null      object
#  6   predicted_pm25               6 non-null      float32
#  7   street                       6 non-null      object
#  8   country                      6 non-null      object
#  9   days_before_forecast_day     6 non-null      int64
# dtypes: datetime64[us, Etc/UTC](1), float32(5), int64(1), object(3)
# memory usage: 488.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
pred_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_forecast.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, pred_file_path)

plt.show()
# Out:
# 2025-11-14 11:55:22,549 WARNING: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
monitor_fg.insert(batch_data, wait=True)
# Out:
# Uploading Dataframe: 100.00% |███████████████████████████████████████████████| Rows 6/6 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: aq_predictions_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1286340/jobs/named/aq_predictions_1_offline_fg_materialization/executions
# 2025-11-14 11:55:43,066 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-14 11:55:46,283 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-11-14 11:57:07,138 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-11-14 11:57:07,332 INFO: Waiting for log aggregation to finish.
# 2025-11-14 11:57:17,595 INFO: Execution finished successfully.
# (Job('aq_predictions_1_offline_fg_materialization', 'SPARK'), None)

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.42s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-16 00:00:00+00:00             3.100000                0.0
# 1 2025-11-12 00:00:00+00:00             7.910250                4.0
# 2 2025-11-13 00:00:00+00:00             8.700000                0.2
# 3 2025-11-11 00:00:00+00:00             5.854000                0.0
# 4 2025-11-10 00:00:00+00:00             5.662334                0.7
# 5 2025-11-14 00:00:00+00:00             3.050000                0.0
# 6 2025-11-15 00:00:00+00:00             1.450000                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant       city  predicted_pm25  \
# 0           10.188700                   237.994659  Stockholm       26.946714
# 1           28.339569                   206.015747  Stockholm       14.276878
# 2           14.277983                   303.690094  Stockholm       16.764250
# 3            9.860649                   199.362671  Stockholm       27.810648
# 4            7.970972                    15.767236  Stockholm       31.771181
# 5           11.525623                   284.470337  Stockholm       13.180638
# 6           10.853866                   275.710510  Stockholm       11.771300
#
#                   street country  days_before_forecast_day
# 0  Sollentuna-E4-Häggvik  Sweden                         1
# 1  Sollentuna-E4-Häggvik  Sweden                         1
# 2  Sollentuna-E4-Häggvik  Sweden                         1
# 3  Sollentuna-E4-Häggvik  Sweden                         1
# 4  Sollentuna-E4-Häggvik  Sweden                         1
# 5  Sollentuna-E4-Häggvik  Sweden                         1
# 6  Sollentuna-E4-Häggvik  Sweden                         1

# %%
#air_quality_fg = fs.get_feature_group(name='air_quality', version=1)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.23s)
#                           date  pm25  pm25_lag_mean country       city  \
# 0    2016-01-21 00:00:00+00:00  28.0      22.666667  Sweden  Stockholm
# 1    2024-04-15 00:00:00+00:00   8.0      14.000000  Sweden  Stockholm
# 2    2017-09-23 00:00:00+00:00  42.0      18.333333  Sweden  Stockholm
# 3    2017-12-28 00:00:00+00:00  45.0       7.666667  Sweden  Stockholm
# 4    2015-12-11 00:00:00+00:00  21.0      21.000000  Sweden  Stockholm
# ...                        ...   ...            ...     ...        ...
# 3660 2018-05-22 00:00:00+00:00  42.0      22.666667  Sweden  Stockholm
# 3661 2023-09-30 00:00:00+00:00  14.0      41.666667  Sweden  Stockholm
# 3662 2018-01-06 00:00:00+00:00   7.0      12.000000  Sweden  Stockholm
# 3663 2022-03-21 00:00:00+00:00  68.0      29.000000  Sweden  Stockholm
# 3664 2025-11-14 00:00:00+00:00   9.0       9.000000  Sweden  Stockholm
#
#                      street                               url
# 0     Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 1     Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 2     Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 3     Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 4     Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# ...                     ...                               ...
# 3660  Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 3661  Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 3662  Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 3663  Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
# 3664  Sollentuna-E4-Häggvik  https://api.waqi.info/feed/@7968
#
# [3665 rows x 7 columns]

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
hindcast_df
# Out:
#                        date  predicted_pm25  pm25
# 3 2025-11-10 00:00:00+00:00       31.771181  10.0
# 2 2025-11-11 00:00:00+00:00       27.810648  16.0
# 0 2025-11-12 00:00:00+00:00       14.276878  12.0
# 1 2025-11-13 00:00:00+00:00       16.764250   6.0
# 4 2025-11-14 00:00:00+00:00       13.180638   9.0

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
hindcast_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_hindcast_1day.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, hindcast_file_path, hindcast=True)
plt.show()

# %% [markdown]
# ### Upload the prediction and hindcast dashboards (png files) to Hopsworks

# %%
dataset_api = project.get_dataset_api()
str_today = today.strftime("%Y-%m-%d")
if dataset_api.exists("Resources/airquality") == False:
    dataset_api.mkdir("Resources/airquality")
dataset_api.upload(pred_file_path, f"Resources/airquality/{city}_{street}_{str_today}", overwrite=True)
dataset_api.upload(hindcast_file_path, f"Resources/airquality/{city}_{street}_{str_today}", overwrite=True)

proj_url = project.get_url()
print(f"See images in Hopsworks here: {proj_url}/settings/fb/path/Resources/airquality")
# Out:
# Uploading /mnt/c/Users/kokia/Documents/egyetem/autumn-25/period2/scalableML/mlfs-book/docs/air-quality/assets/…
# Uploading /mnt/c/Users/kokia/Documents/egyetem/autumn-25/period2/scalableML/mlfs-book/docs/air-quality/assets/…
# See images in Hopsworks here: https://c.app.hopsworks.ai:443/p/1286340/settings/fb/path/Resources/airquality

# %% [markdown]
# ---
